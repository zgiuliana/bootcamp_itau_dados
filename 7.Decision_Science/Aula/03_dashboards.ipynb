# %% [markdown]
# # Construindo Dashboards Analíticos
#
# ## Objetivo
#
# Nesta seção veremos como construir **Dashboards Analiticos** com foco em tranformar os dados armazenados em informação para tomada de decisão em nossas empresas.
#
# ## Recursos para a Aula
#
# + **PostgreSQL**
#
# + **PowerBI Desktop**
#
# Agora que já sabemos a construir querys e objetos com SQL vamos aprender a entregar valor para o négocio construindo **Dashboards** que transformem nossos dados armazenados nas tabelas de nossos bancos de dados em informação de alto valor para tomada de decisão em nossas empresas.
#
# Para que isso seja possivel precisamos de um software que transforme os dados armazenados em nossos bancos de dados em gráficos de fácil compreensão para que as pessoas que possuam conhecimento do negócio passam interpreta-los de forma analítica.
#
# Existem diversos softwares que podemos utilizar para tal atividades, dentre eles temos:
#
# + **Tableau**
#
# + **Microsoft Power BI**
#
# + **MoData**
#
# + **Qlick Sense**
#
# + **Looker**
#
# Nesta aula iremos utilizar o **Microsoft Power BI**. Esta é uma ferramenta que nasceu dentro do Excel e desde que foi separada deste vem crescendo e sendo aperfeiçoada.
#
# Para instalala basta [clicar no link](https://powerbi.microsoft.com/pt-br/downloads/), fazer o download do **Microsoft Power BI Desktop** e fazer a instalação diretamente *(Next-Next-Finish)*:
#
# ![power_bi_01](https://s3-sa-east-1.amazonaws.com/lcpi/68d81657-731c-48ae-8bdc-d095dfddfb53.PNG)
#
#
# ## Dashboards usando Microsoft Power BI
#
# Vamos construir um dashboard baseado em nosso banco de dados **Northwind** *(6.Praticando SQL)*.
#
# O banco de dados **Northwind** é um banco de dados de exemplo usado pela Microsoft para demonstrar o
# recursos de alguns de seus produtos, incluindo SQL Server e Microsoft Access.
#
# O banco de dados contém os dados de vendas da **Northwind Traders**, uma importação e exportação de alimentos especiais fictícios
# empresa.
#
# ### Preparando o ambiente...
#
# + Conectado ao Banco de Dados RDS Postgres, crie o database **northwind**.
# ~~~sql
# /*Estrutura do database northwind*/
#
# CREATE DATABASE northwind
#     WITH
#     OWNER = letscode
#     ENCODING = 'UTF8'
#     CONNECTION LIMIT = -1;
# ~~~
#
# + Vamos utilizar o arquivo [northwind.sql](https://s3-sa-east-1.amazonaws.com/lcpi/07d483a2-9c46-4969-8ab9-e45e2e8d2ac3.sql) para criar as tabelas **Customers**, **Categories**, **Employees**, **Order_Details**, **Orders**, **Products**, **Shippers**, **Suppliers** e inserir registros nessas tabelas.
#
# + Configurar o **PostgreSQL Binary Path**
#
# ![power_bi_02](https://s3-sa-east-1.amazonaws.com/lcpi/603241fc-6df1-4d8f-9441-22364332cde5.PNG)
#
# + Exportar as tabelas **categories**, **customers**, **employees**, **order_details**, **orders**, **products**, **shippers** e **suppliers** para o formato `.csv` usando o **pgAdmin4**
#
# ###### Import/Export do pgAdmin4...
# ![power_bi_06](https://s3-sa-east-1.amazonaws.com/lcpi/bd07bfaf-2165-4273-bfac-779d16ca7d2f.PNG)
#
# ![power_bi_04](https://s3-sa-east-1.amazonaws.com/lcpi/5569f49c-b248-4ba1-9598-fca328ab387a.PNG)
#
#
# + Importar os arquivos `.csv`. Se for necessário, tratar os dados no Power BI
#
# ![power_bi_07](https://s3-sa-east-1.amazonaws.com/lcpi/7ff09f7f-2e53-4db1-8101-4a5207ed4ccf.PNG)
#
# + Checar relacionamento entre as tabelas
#
# ![power_bi_08](https://s3-sa-east-1.amazonaws.com/lcpi/17fb7411-5e9b-489a-b61e-430db4345cd8.PNG)
#
# + Construir um dashboard no Power BI
#
# ![power_bi_09](https://s3-sa-east-1.amazonaws.com/lcpi/be6b6096-2dbe-4e49-9c4c-eea28837cd6c.PNG)
#
#
# ### Referências
#
# **Dashboard: [Northwind_BI.pbix](https://s3-sa-east-1.amazonaws.com/lcpi/e6e0a5e1-d7b2-43c7-906e-58dd8be42dbf.pbix)**
#
# [O que é Power BI? Como funciona?](https://www.youtube.com/watch?v=kgW2GLbggck)
#
# [Como analisar dados com o Power Bi?](https://www.youtube.com/watch?v=uPlUjrKzd48)
#
# [Como fazer um dashboard no Power BI?](https://www.youtube.com/watch?v=W7psNc0PC04)
#
# [Deu M no Power BI - Substituir Caracteres em Lote](https://www.youtube.com/watch?v=wwmaNbbcQdM)
#
# [Importar CSV no Power BI](https://www.youtube.com/watch?v=GFEFM5TyM3s)
