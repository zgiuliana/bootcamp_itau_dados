# %%
import numpy as np
import pandas as pd
import statistics as st

# %% [markdown]
# #### 1
# Crie uma lista do Python que contenha 10 inteiros aleatórios (entre 0 e 100). Em seguida, a partir da lista criada anteriormente, crie um array do Numpy, utilizando a função array.

# %%
from random import randint
lista=[randint(0,100) for i in range(10)]
np.array(lista)
# Out:
# array([76, 57, 55, 83,  5,  1, 22, 48, 27, 84])

# %% [markdown]
# #### 2
# Crie um array com 10 elementos (iniciando em zero), em que os elementos tenham um intervalo de 3 unidades entre si.

# %%
np.arange(0,30,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21, 24, 27])

# %% [markdown]
# #### 3
# Crie um array com 40 elementos entre 0 e π.

# %%
np3=np.linspace(0,np.pi,40)
np3
# Out:
# array([0.        , 0.08055366, 0.16110732, 0.24166097, 0.32221463,
#        0.40276829, 0.48332195, 0.5638756 , 0.64442926, 0.72498292,
#        0.80553658, 0.88609024, 0.96664389, 1.04719755, 1.12775121,
#        1.20830487, 1.28885852, 1.36941218, 1.44996584, 1.5305195 ,
#        1.61107316, 1.69162681, 1.77218047, 1.85273413, 1.93328779,
#        2.01384144, 2.0943951 , 2.17494876, 2.25550242, 2.33605608,
#        2.41660973, 2.49716339, 2.57771705, 2.65827071, 2.73882436,
#        2.81937802, 2.89993168, 2.98048534, 3.061039  , 3.14159265])

# %% [markdown]
# #### 4
# Crie um array com 40 elementos, todos iguais a 6.

# %%
np4=np.full(40,6)
np4
# Out:
# array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6])

# %% [markdown]
# #### 5
# Divida o array obtido na Questão 4 por 3 e, em seguida, multiplique-o pelo array obtido na Questão 3.

# %%
np5=(np3/3)*np4
np5
# Out:
# array([0.        , 0.16110732, 0.32221463, 0.48332195, 0.64442926,
#        0.80553658, 0.96664389, 1.12775121, 1.28885852, 1.44996584,
#        1.61107316, 1.77218047, 1.93328779, 2.0943951 , 2.25550242,
#        2.41660973, 2.57771705, 2.73882436, 2.89993168, 3.061039  ,
#        3.22214631, 3.38325363, 3.54436094, 3.70546826, 3.86657557,
#        4.02768289, 4.1887902 , 4.34989752, 4.51100484, 4.67211215,
#        4.83321947, 4.99432678, 5.1554341 , 5.31654141, 5.47764873,
#        5.63875604, 5.79986336, 5.96097068, 6.12207799, 6.28318531])

# %% [markdown]
# #### 6
# Crie um array com 40 números aleatórios, distribuídos uniformemente, entre [0, 5). Em seguida, some-o com o array obtido na Questão 5.
#
# OBS.: Utilize a seed 17 para a criação do array aleatório.

# %%
np.random.seed(17)
np6=np.random.uniform(0, 5, 40)+np5
np6
# Out:
# array([ 1.47332501,  2.81404109,  1.27981857,  0.82282374,  4.57935656,
#         4.08720419,  4.15424837,  4.00576568,  1.48417311,  3.23903386,
#         6.33948909,  2.07240387,  6.2534983 ,  6.48084773,  2.51147075,
#         5.67870281,  5.33647389,  5.72639063,  5.3175748 ,  4.4759798 ,
#         4.7107749 ,  6.19079815,  5.52459812,  7.64897181,  5.9589975 ,
#         4.74720249,  4.94332368,  4.62610427,  8.1011908 ,  6.13369892,
#         5.82708883,  9.15114639,  7.9953897 ,  5.72824016,  8.2026416 ,
#         6.43354977,  9.18367529,  6.553332  ,  8.34705832, 10.72309748])

# %% [markdown]
# #### 7
# Para cada elemento do array da questão anterior, calcule:
#
# - O seno
# - O cosseno
# - O log na base 10
# - O valor arredondado para inteiro

# %%
np6_sin=np.sin(np6)
np6_cos=np.cos(np6)
np6_log10=np.log10(np6)
np6_round=np.round(np6)

# %% [markdown]
# #### 8
# Lembra que você obteve o seno de um array na questão anterior? Agora, você deve obter um array apenas com os valores positivos do array resultante daquela operação do seno.

# %%
np6_sin[np6_sin>=0]
# Out:
# array([0.99525343, 0.32172573, 0.95796382, 0.73306933, 0.99625055,
#        0.05627404, 0.87681073, 0.19637781, 0.58924326, 0.97905898,
#        0.96959911, 0.27022967, 0.99001853, 0.93983136, 0.14979849,
#        0.23877355, 0.26687281, 0.88088072])

# %%
np3=np.linspace(0,np.pi,40)
np4=np.full(40,6)
np5=(np3/3)*np4
np.random.seed(17)
np6=np.random.uniform(0, 5, 40)+np5
np6_sin=np.sin(np6)
np6_sin[np6_sin>=0]
# Out:
# array([0.99525343, 0.32172573, 0.95796382, 0.73306933, 0.99625055,
#        0.05627404, 0.87681073, 0.19637781, 0.58924326, 0.97905898,
#        0.96959911, 0.27022967, 0.99001853, 0.93983136, 0.14979849,
#        0.23877355, 0.26687281, 0.88088072])

# %% [markdown]
# #### 9
# Para os dados contidos no array da Q6, obtenha:
#
# - O valor mínimo
# - O valor máximo
# - A posição do valor mínimo
# - A posição do valor máximo
# - A média dos dados
# - A mediana
# - A moda
# - A variância
# - O desvio padrão
# - O array ordenado (forma crescente)

# %%
print('O valor mínimo do Array é:',np.min(np6))
print('O valor máximo do Array é:',np.max(np6))
print('A posição do menor valor do array é:',np.argmin(np6))
print('A posição do menor valor do array é:',np.argmax(np6))
print('A média dos valores do array é:',np.mean(np6))
print('A mediana dos valores do array é:',np.median(np6))
#Arredondei, pois com muitas casas decimais não havia nenhum número repetido
print('A moda dos valores do array é:',st.mode(np.round(np6,1)))
print('A variância dos valores do array é:',np.var(np6))
print('O desvio padrão dos valores do array é:',np.std(np6))
print('O array ordenado é:',np.sort(np6))
# Out:
# O valor mínimo do Array é: 0.8228237376625789
# O valor máximo do Array é: 10.723097477965581
# A posição do menor valor do array é: 3
# A posição do menor valor do array é: 39
# A média dos valores do array é: 5.371587551309284
# A mediana dos valores do array é: 5.601650466802789
# A moda dos valores do array é: 5.7
# A variância dos valores do array é: 5.184569337598459
# O desvio padrão dos valores do array é: 2.2769649399141962
# O array ordenado é: [ 0.82282374  1.27981857  1.47332501  1.48417311  2.07240387  2.51147075
#   2.81404109  3.23903386  4.00576568  4.08720419  4.15424837  4.4759798
#   4.57935656  4.62610427  4.7107749   4.74720249  4.94332368  5.3175748
#   5.33647389  5.52459812  5.67870281  5.72639063  5.72824016  5.82708883
#   5.9589975   6.13369892  6.19079815  6.2534983   6.33948909  6.43354977
#   6.48084773  6.553332    7.64897181  7.9953897   8.1011908   8.2026416
#   8.34705832  9.15114639  9.18367529 10.72309748]

# %% [markdown]
# #### 10
# Crie outro array aleatório, porém, dessa vez, com 25 elementos inteiros, no intervalo [50, 100). Em seguida, converta esse array em uma matriz 5 x 5.

# %%
np10=np.random.uniform(50, 100, 25)
matriz = np10.reshape((5, 5))
matriz
# Out:
# array([[97.8094136 , 99.34052296, 91.46894217, 76.89447298, 54.17688102],
#        [65.69437445, 55.30567246, 60.24543229, 66.27591982, 75.08044936],
#        [93.91593769, 63.05044717, 76.50683863, 92.19313211, 56.82822432],
#        [70.01120051, 78.42426433, 59.30206063, 50.68579666, 79.63945279],
#        [50.7857616 , 79.29968618, 70.43314507, 61.43119709, 59.49418689]])

# %% [markdown]
# #### 11
# Construa a matriz ilustrada pela figura abaixo. Em seguida, obtenha os slices (fatiamentos) destacados em cada cor. Em outras palavras, utilizando o conceito de slices, crie um novo array que contenha os dados destacados em vermelho, azul, roxo e verde.

# %%
array=np.arange(0,6)
m11=np.vstack((array, array+10, array+20,array+30,array+40,array+50))
print('Vermelho:',m11[0,3:5])
print('Azul:',m11[:,2:3])
print('Roxo',m11[2:5:2,0::2])
print('Verde:',m11[4:,4:])
# Out:
# Vermelho: [3 4]
# Azul: [[ 2]
#  [12]
#  [22]
#  [32]
#  [42]
#  [52]]
# Roxo [[20 22 24]
#  [40 42 44]]
# Verde: [[44 45]
#  [54 55]]

# %% [markdown]
# #### 12
# Nesse desafio, iremos praticar o conceito de indexação em imagens! Pois é, caso você ainda não saiba, as imagens são formadas com conjuntos de pixels, e esses pixels são números inteiros (entre 0 e 255). Sendo assim, quando carregamos uma imagem no Python, essa imagem será armazenada em um matriz (Numpy), ou seja, cada pixel dessa imagem será um elemento dessa matriz.
#
# No entanto, é importante que você também saiba que uma imagem colorida é composta por três matrizes, visto que uma imagem colorida é formada por 3 cores básicas: vermelho, verde e azul. Esse é o famoso padrão RGB. Portanto, sua imagem será armazenada em um array tridimensional.
#
# Sabendo disso, sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical. Mas, calma... vamos te dar uma ajuda.
#
# Primeiro, você precisa instalar a biblioteca skimage para carregar a imagem, além da biblioteca do matplotlib para exibir a imagem (veremos essa biblioteca com mais detalhes nesse curso!), caso você ainda não tenha elas instaladas, claro. Para isso, utilize o comando pip install scikit-image matplotlib, se você estiver utilizando o pip, ou conda install scikit-image matplotlib, se estiver utilizando o Anaconda.
#
# Em seguida, observe o código abaixo; ele te mostra como você pode carregar uma imagem e exibi-la. Lembrando... Sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical.

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('/home/zgiuliana/Imagens/the-office-steve-carell.jpg') # Carregamento da imagem

rows, columns, channels = img.shape

plt.imshow(img[:rows//2,:,:]) # Exibição da imagem

# %%
plt.imshow(img[:, columns//2:, :]) # Exibição da imagem

# %%
plt.imshow(img[:rows//2, columns//2:,:]) # Exibição da imagem
