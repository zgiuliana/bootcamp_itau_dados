# %% [markdown]
# # Antes de começar....

# %% [markdown]
# ...deixe o download rolando.
#
# - [Windows](https://www.enterprisedb.com/postgresql-tutorial-resources-training?cid=437)
# - [Mac Os X](https://www.enterprisedb.com/postgresql-tutorial-resources-training?cid=438)
# - [Linux](https://www.postgresql.org/download/linux/ubuntu/)
#
# Instalaremos juntos mais tarde! 😁

# %% [markdown]
# # Aula 01: Introdução a Banco de dados e SQL

# %% [markdown]
# Na aula de hoje iremos explorar bancos de dados e a linguagem SQL (Structured Query Language).

# %% [markdown]
# # Habilidades a serem desenvolvidas

# %% [markdown]
# Ao final da aula, o aluno deve:
# 1. Entender o que são e para que servem os bancos de dados (BDs);
# 1. Saber a diferença entre diferentes tipos de BDs;
# 1. Diferenciar as linguagens de BDs;
# 1. Reconhecer os tipos de variáveis;
# 1. Ter instalado um servidor local e configurado a primeira base de dados de exemplo;
# 1. Estar confortável com os commandos `SELECT` e `WHERE` suas opções.

# %% [markdown]
# # Motivação

# %% [markdown]
# ![image_3685bb3d-2bcb-4d92-bf87-eb79e9b2520620210710_103331.jpg](attachment:image_3685bb3d-2bcb-4d92-bf87-eb79e9b2520620210710_103331.jpg)

# %% [markdown]
# # Introdução

# %% [markdown]
# [Material](https://docs.google.com/presentation/d/1WYo5P0iICabZ4pTheyFlN6yFSvlEBVoD/edit#slide=id.p7)

# %% [markdown]
# # Configurando nosso primeiro BD

# %% [markdown]
# 1. Instale o arquivo que baixamos no começo da aula.
#         - Durante a instação ele vai te pedir a senha e a porta. **Senha:** postgres e **porta:** 5432.
# 1. Clique-direito em Servers -> Create -> Server...
#         - Aba General -> Name = localhost
#         - Aba Connection -> Hostname/address = localhost
# 1. Servers -> Clique-direito em Datababases -> Create -> Database...
#         - Aba General => Database = northwind
# 1. Servers -> localhost -> Databases -> clique-direito em northwind -> Query tool
#         - Open -> suba o arquivo northwind.sql
#         - Execute o conjunto de instruções
# 1. Servers -> localhost -> Databases -> northwind -> Schemas -> clique-direito em Tables -> Refresh
#         - todas as tables que foram criadas devem aparecer

# %% [markdown]
# # Consultando dados em uma tabela

# %% [markdown]
# ## SELECT
# Selecione todos os dados da tabela customers.

# %% [markdown]
# >

# %% [markdown]
# ## Escolher colunas
# Escolha apenas as colunas company_name e city da tabela customers.

# %% [markdown]
# >

# %% [markdown]
# ## LIMIT
# Selecione as apenas 10 linhas da tabela consumidores.

# %% [markdown]
# >

# %% [markdown]
# ## DISTINCT
# Encontre todas as cidades dos consumidores.

# %% [markdown]
# >

# %% [markdown]
# ## Alias: AS
# Renomeie a coluna_postal code como CEP.

# %% [markdown]
# >

# %% [markdown]
# ## WHERE
#
# ### Operadores de igualdade: >, <, =, <>
#
# Selecione o nome das empresas de consumidores que ficam em Vancouver.

# %% [markdown]
# >

# %% [markdown]
# Selecione todas as empresas que não ficam em Vancouver.

# %% [markdown]
# >

# %% [markdown]
# ### AND
# Selecione nome das empresa e nome dos contatos de empresas que ficam na Alemanha e o contato seja representante de vendas.

# %% [markdown]
# >

# %% [markdown]
# ### OR
# Selecione o nome e cidade das empresas que estão em São Paulo ou no Rio de Janeiro.

# %% [markdown]
# >

# %% [markdown]
# ### IN
# Selecione todas as empresas escandinavas (Suécia, Dinamarca, Finlândia e Noruega).

# %% [markdown]
# >

# %% [markdown]
# ### IS NULL & IS NOT NULL
# Selecione todas as empresas que tem valores preenchidos no campo região.

# %% [markdown]
# >

# %% [markdown]
# ### LIKE
# Selecione todas as empresas em que os representantas sejam do setor de vendas.

# %% [markdown]
# >

# %% [markdown]
# ### BETWEEN
# Selecione todos os registros da tabela employess que tenham employee_id entre 10 e 25.

# %% [markdown]
# >

# %% [markdown]
# # Exercícios

# %% [markdown]
# Enviar para o email filipe.furlan@letcode.com.br até **2021/07/31** um arquivo de texto (`785_firstname_lastname_aula01.sql`) com a resolução dos exercicios abaixo (exceto o 6).
#
# IMPORTANTE: Inserir uma linha de comentário `-- exercicio XX` (XX = 1, 2A, 2B etc) antes de cada solução.

# %% [markdown]
# 1. Selecione os id's únicos de territórios da tabela employee_territories.
# 1. Selecione da tabela empolyees:
#     1. Todos os nomes dos empregados;
#     1. Os sobrenomes distintos dos empregrados;
#     1. Empregados que nasceram após 1970;
#     1. Empregados que foram contratados em 1993;
#     1. Empregados que nasceram entre 1980 e 1985 (inclusos);
#     1. Empregados que nasceram em 1963 e foram contratados em 1993;
#     1. Todos os empregrados que reportam o chefe de id 5;
#     1. Todos os empregados que moram em Seattle ou Kirkland.
# 1. Selecione da tabela order_details:
#     1. Produtos (product_id) com mais de 50 unidades vendidas;
#     1. Produtos com mais de 0.2 de desconto;
#     1. Produtos com 0.05 ou menos de desconto;
# 1. Selecione da tabels orders:
#     1. Ordens realizadas antes Setembro de 1996.
#     1. Ordens enviadas em Setembro de 1996.
#     1. Ordens que possuam o campo região preenchido.
#     1. As primeiras 5 linhas da tabela, reescrevendo o nome das colunas de data em português.
# 1. Selecione da tabela suppliers:
#     1. Todos os contatos cujo nome comece com a letra M;
#     1. Todos os contatos que tenham a palavra manager no titulo;
#     1. Todos os contatos que trabalhem com vendas e morem nos países nórdicos.
# 1. Use o arquivo `estados_cidades.sql` para criar um novo schema no Postgres (**será utilizado nas próximas aulas!**).
