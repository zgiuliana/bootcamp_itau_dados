# %% [markdown]
# # Motivação

# %% [markdown]
# ![tables-dribbble.jpg](attachment:tables-dribbble.jpg)

# %% [markdown]
# # Aula 04: Consultando tabelas múltiplas

# %% [markdown]
# Na aula de hoje iremos aplicar todos conceitos vistos até agora e aprender a sumarizar a agregar informações.

# %% [markdown]
# [Material](https://docs.google.com/presentation/d/1HgYFtjtcgPEUG9u5K62Bk6S2KYxVLKfESXikDZOlD0U/edit#slide=id.p1)

# %% [markdown]
# # Habilidades a serem desenvolvidas

# %% [markdown]
# Ao final da aula, o aluno deve:
# 1. Entender e saber aplicar os diferentes tipos de join;
# 1. Agregar queries via UNION;
# 1. Aplicar os conceitos das aulas anteriores.

# %% [markdown]
# # Tabelas Multiplas

# %% [markdown]
# Exemplo de uma uma escola (Let's Code?).
#
# Tabela turma:
# ![table_turma.PNG](attachment:table_turma.PNG)
#
# Tabela aluno:
# ![table_aluno.PNG](attachment:table_aluno.PNG)
#
# Tabela turma_aluno:
# ![table_aluno_turma.PNG](attachment:table_aluno_turma.PNG)

# %% [markdown]
# ## Criando a base de dados

# %% [markdown]
# 1. Inicie o pgAdmin4.
# 1. Servers -> localhost -> Clique-direito em Datababases -> Create -> Database...
#         - Aba General => Database = escola
# 1. Servers -> localhost -> Databases -> clique-direito em escola -> Query tool
#         - Open -> suba o arquivo escola_785.sql
#         - Execute o conjunto de instruções
# 1. Servers -> localhost -> Databases -> escola_785 -> Schemas -> clique-direito em Tables -> Refresh
#         - todas as tables que foram criadas devem aparecer

# %% [markdown]
# # SQL: JOINS

# %% [markdown]
# ## INNER

# %% [markdown]
# Retorna somente os valores presentes nas duas tabelas!
#
# ![inner_join.PNG](attachment:inner_join.PNG)

# %% [markdown]
# **Exemplo:** Enriquecer a tabela `turma_aluno` com os dados dos alunos.

# %% [markdown]
# >

# %% [markdown]
# Resultado:

# %% [markdown]
# ## LEFT

# %% [markdown]
# Retorna **todos os dados** da tabela da **esquerda** mais os registros correspondentes da tabela da direita.
# **OBS:** Duplica registros.
#
# ![left_join.PNG](attachment:left_join.PNG)

# %% [markdown]
# **Exemplo:** Enriquecer a tabela `aluno` com os dados da tabela `turma_aluno` via `left_join`.

# %% [markdown]
# >

# %% [markdown]
# Resultado:

# %% [markdown]
# ## RIGHT

# %% [markdown]
# Retorna **todos os dados** da tabela da **direita** mais os registros correspondentes da tabela da esquerda.
# **OBS 1:** Duplica registros.
# **OBS 2:** Pouco utilizado na prática!
#
# ![right_join.PNG](attachment:right_join.PNG)

# %% [markdown]
# **Exemplo:** Enriquecer a tabela `aluno` com os dados da tabela `turma_aluno` via `right_join`.

# %% [markdown]
# >

# %% [markdown]
# Resultado:

# %% [markdown]
# ## FULL OUTER

# %% [markdown]
# Retorna **todos os dados** das duas tabelas.
# **OBS 1:** Duplica registros.
#
# ![full_join.PNG](attachment:full_join.PNG)

# %% [markdown]
# **Exemplo:** Encontrar alunos que não estejam matriculados!
#
# Juntar as tabelas `aluno` com os dados da tabela `turma_aluno`  via `outer_join`.

# %% [markdown]
# >

# %% [markdown]
# Resultado:

# %% [markdown]
# # Multiplos Joins e o uso de ALIAS

# %% [markdown]
# **Execício 1:** Faça uma query retorne uma tabela no sequinte formato:
#
# ` id_turma_aluno | nome_do_curso | professor | nome_do_aluno | matricula`

# %% [markdown]
# Query:

# %% [markdown]
# Resultado:

# %% [markdown]
# # Sumarizando, agregando, ordenando e tudo mais em múltiplas tabelas

# %% [markdown]
# **Exercício 2:** Faça um relatório que apresente o número de alunos por turma. O resultado deve ser no formato `nome_do_curso | numero_de_alunos`.

# %% [markdown]
# Query:

# %% [markdown]
# Resultado:

# %% [markdown]
# **Exercício 3:** Quantos alunos um professor atende? O resultado deve ser no formato `nome_do_professor | numero_de_alunos`. Note que o mesmo aluno pode estar em mais de uma turma!

# %% [markdown]
# Query:

# %% [markdown]
# Resultado:

# %% [markdown]
# # SQL: UNION & UNION ALL

# %% [markdown]
# Juntam os resultados de duas queries em uma única saída.
# **UNION:** Remove duplicados (linhas cujos valores em todas as colunas são os mesmos);
# **UNION ALL:** Não remove duplicados.
#
# **Exemplo:** Una os resultados das duas queries acima.
#
# **Exemplo prático:** Agregar informações de transações de cartões de crédito e débido,que geralmente são armazenadas em tabelas diferentes.

# %% [markdown]
# Query:

# %% [markdown]
# Resultado:

# %% [markdown]
# # Execícios

# %% [markdown]
# Enviar para o email filipe.furlan@letscode.com.br até **2021/07/31** um arquivo de texto (`785_firstname_lastname_aula04.sql`) com a resolução dos exercicios abaixo.
#
# IMPORTANTE: Inserir uma linha de comentário `-- exercicio XX` (XX = 1, 2A, 2B etc) antes de cada solução.

# %% [markdown]
# 1. Usando a database `estados_cidades` (criada na aula 01):
#     1. Faça um relatório que traga o número de cidades por estado (nome por extenso) e ordene:
#         1. Ordem alfabética por nome do estado;
#         1. Do maior para o menor número de municípios.
#     1. Uma lista com que as cidades (nome por extenso) que tem municipíos com nomes repetidos.
#     1. Uma lista com que os estados e as cidades (nome por extenso) que tem municipíos com nomes repetidos.
#         1. Por que o resultado é diferente?
# 1. No banco de dados do Northwind, obtenha:
#     1. Uma lista dos 10 clientes que realizaram o maior número de pedidos, bem como o número de pedidos de cada, ordenados em ordem decrescente de nº de pedidos.
#     1. Uma tabela com o valor médio das vendas em cada mês, ordenando do mês com mais vendas ao mês com menos vendas.

# %% [markdown]
# # Resumindo...

# %% [markdown]
# ![Screenshot_20201008-221857_2.png](attachment:Screenshot_20201008-221857_2.png)
